# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mtcars.csv', nrows=5)
df
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.rename(columns={'model':'MODEL'}, inplace=True)
df
# Out:
#                MODEL   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.rename(columns={'MODEL':'model1', 'mpg':'MPG'}, inplace=True)
df
# Out:
#               model1   MPG  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.columns
# Out:
# Index(['model1', 'MPG', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.columns.str.replace(r'p', '_')
# Out:
# Index(['model1', 'MPG', 'cyl', 'dis_', 'h_', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(r'p', '_')

# %%
df
# Out:
#               model1   MPG  cyl   dis_   h_  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.columns = df.columns.str.upper()
df
# Out:
#               MODEL1   MPG  CYL   DIS_   H_  DRAT     WT   QSEC  VS  AM  GEAR  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    CARB
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# หรือทำรวมกัน df.columns = df.columns.str.upper().str.replace(r'p', '_')

# %% [markdown]
# ## Rename index

# %%
df.index.names
# Out:
# FrozenList([None])

# %%
df.index.names=['id']
df
# Out:
#                MODEL1   MPG  CYL   DIS_   H_  DRAT     WT   QSEC  VS  AM  \
# id
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#     GEAR  CARB
# id
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2

# %%
df.set_index(['MODEL1', 'MPG'], inplace=True)
df
# Out:
#                         CYL   DIS_   H_  DRAT     WT   QSEC  VS  AM  GEAR  \
# MODEL1            MPG
# Mazda RX4         21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag     21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710        22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive    21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout 18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                         CARB
# MODEL1            MPG
# Mazda RX4         21.0     4
# Mazda RX4 Wag     21.0     4
# Datsun 710        22.8     1
# Hornet 4 Drive    21.4     1
# Hornet Sportabout 18.7     2

# %%
df.index.names=['model', 'mpg']
df
# Out:
#                         CYL   DIS_   H_  DRAT     WT   QSEC  VS  AM  GEAR  \
# model             mpg
# Mazda RX4         21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag     21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710        22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive    21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout 18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                         CARB
# model             mpg
# Mazda RX4         21.0     4
# Mazda RX4 Wag     21.0     4
# Datsun 710        22.8     1
# Hornet 4 Drive    21.4     1
# Hornet Sportabout 18.7     2
