# %%
import pandas as pd
import datetime as tm

# %%
str(tm.datetime.now())
# Out:
# '2018-06-12 13:27:00.157963'

# %% [markdown]
# ## The greatest films of all time: download the data
# https://www.theguardian.com/news/datablog/2010/oct/16/greatest-films-of-all-time
# https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=0

# %%
#https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=2
url = 'https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/export?gid=2&format=csv'  #แก้หลัง /edit
df = pd.read_csv(url)
df
# Out:
#     Entry     Cat                          Film  \
# 0       1  Comedy                    Annie Hall
# 1       2  Comedy                         Borat
# 2       3  Comedy              Some Like it Hot
# 3       4  Comedy                  Team America
# 4       5  Comedy                Dr Strangelove
# 5       5  Comedy               The Ladykillers
# 6       7  Comedy                     Duck Soup
# 7       7  Comedy                      Rushmore
# 8       9  Comedy        Kind Hearts & Coronets
# 9      10  Comedy  Monty Python’s Life of Brian
# 10     11  Comedy                     Airplane!
# 11     12  Comedy                      Election
# 12     12  Comedy               His Girl Friday
# 13     12  Comedy              The Big Lebowski
# 14     15  Comedy            This Is Spinal Tap
# 15     16  Comedy              Bringing Up Baby
# 16     17  Comedy  There’s Something About Mary
# 17     18  Comedy            Dazed and Confused
# ...
