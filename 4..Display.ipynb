# %% [markdown]
# # Display Website

# %%
from IPython.display import IFrame, YouTubeVideo, SVG, HTML

# %%
IFrame("https://matplotlib.org/examples/color/named_colors.html", width = 1000, height = 400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://matplotlib.org/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Display PDF

# %%
IFrame("http://datacamp-community.s3.amazonaws.com/f9511cf4-abb9-4f52-9663-ea93b29ee4b7", width = 1000, height = 800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="http://datacamp-community.s3.amazonaws.com/f9511cf4-abb9-4f52-9663-ea93b29ee4b7"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Embed Youtube

# %%
#https://www.youtube.com/watch?v=YPgImo9kcbg
YouTubeVideo('YPgImo9kcbg',600,400)

# %%
IFrame("https://abload.de/img/detroit01vtqpt.jpg", 1000, 1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="https://abload.de/img/detroit01vtqpt.jpg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Display HTML

# %%
s = '''<span style=color:red;font-size:150%>Cornor</span> <span style=color:springgreen;font-size:200%>GREEN</span>'''
HTML(s)
# Out:
# <span style=color:red;font-size:150%>Cornor</span> <span style=color:springgreen;font-size:200%>GREEN</span>

# %%
pic = '''<img src = https://gamingroom.co/wp-content/uploads/2018/05/2.jpg>'''

HTML(pic)
# Out:
# <img src = https://gamingroom.co/wp-content/uploads/2018/05/2.jpg>
