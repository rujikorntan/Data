# %%
import pandas as pd

# %%
df = pd.read_csv('datasheet/forex-sci.csv')
df
# Out:
#         PAIR       DATE     OPEN    HIGH     LOW    CLOSE
# 0    ^EURUSD   4/2/2008  1.48000  1.4849  1.4792  1.48300
# 1    ^EURUSD   5/2/2008  1.48290  1.4832  1.4620  1.46480
# 2    ^EURUSD   6/2/2008  1.46490  1.4672  1.4588  1.46320
# 3    ^EURUSD   7/2/2008  1.46320  1.4652  1.4438  1.44840
# 4    ^EURUSD   8/2/2008  1.44890  1.4548  1.4449  1.45060
# 5    ^EURUSD  11/2/2008  1.45050  1.4578  1.4480  1.45200
# 6    ^EURUSD  12/2/2008  1.45190  1.4615  1.4495  1.45830
# 7    ^EURUSD  13/2/2008  1.45830  1.4599  1.4530  1.45750
# 8    ^EURUSD  14/2/2008  1.45750  1.4648  1.4547  1.46420
# 9    ^EURUSD  15/2/2008  1.46410  1.4709  1.4623  1.46820
# 10   ^EURUSD  18/2/2008  1.46800  1.4690  1.4609  1.46550
# 11   ^EURUSD  19/2/2008  1.46600  1.4757  1.4639  1.47270
# 12   ^EURUSD  20/2/2008  1.47270  1.4739  1.4612  1.47140
# 13   ^EURUSD  21/2/2008  1.47150  1.4837  1.4700  1.48140
# 14   ^EURUSD  22/2/2008  1.48120  1.4863  1.4787  1.48290
# ...

# %%
df['CLOSE_USD_BAHT'] = df['CLOSE']*0.031
df.head()
# Out:
#       PAIR      DATE    OPEN    HIGH     LOW   CLOSE  CLOSE_USD_BAHT
# 0  ^EURUSD  4/2/2008  1.4800  1.4849  1.4792  1.4830        0.045973
# 1  ^EURUSD  5/2/2008  1.4829  1.4832  1.4620  1.4648        0.045409
# 2  ^EURUSD  6/2/2008  1.4649  1.4672  1.4588  1.4632        0.045359
# 3  ^EURUSD  7/2/2008  1.4632  1.4652  1.4438  1.4484        0.044900
# 4  ^EURUSD  8/2/2008  1.4489  1.4548  1.4449  1.4506        0.044969

# %%
df['CLOSE_USD_BAHT'] = df['CLOSE_USD_BAHT'].round(4)
df.head()
# Out:
#       PAIR      DATE    OPEN    HIGH     LOW   CLOSE  CLOSE_USD_BAHT
# 0  ^EURUSD  4/2/2008  1.4800  1.4849  1.4792  1.4830          0.0460
# 1  ^EURUSD  5/2/2008  1.4829  1.4832  1.4620  1.4648          0.0454
# 2  ^EURUSD  6/2/2008  1.4649  1.4672  1.4588  1.4632          0.0454
# 3  ^EURUSD  7/2/2008  1.4632  1.4652  1.4438  1.4484          0.0449
# 4  ^EURUSD  8/2/2008  1.4489  1.4548  1.4449  1.4506          0.0450

# %%
df['tran_PAIR'] = df.PAIR.str[1:7] 
df.head()
# Out:
#       PAIR      DATE    OPEN    HIGH     LOW   CLOSE  CLOSE_USD_BAHT tran_PAIR
# 0  ^EURUSD  4/2/2008  1.4800  1.4849  1.4792  1.4830          0.0460    EURUSD
# 1  ^EURUSD  5/2/2008  1.4829  1.4832  1.4620  1.4648          0.0454    EURUSD
# 2  ^EURUSD  6/2/2008  1.4649  1.4672  1.4588  1.4632          0.0454    EURUSD
# 3  ^EURUSD  7/2/2008  1.4632  1.4652  1.4438  1.4484          0.0449    EURUSD
# 4  ^EURUSD  8/2/2008  1.4489  1.4548  1.4449  1.4506          0.0450    EURUSD

# %%
df.LOW.mean()
# Out:
# 1.4403095970695965

# %%
df.describe()
# Out:
#              OPEN        HIGH         LOW       CLOSE  CLOSE_USD_BAHT
# count  273.000000  273.000000  273.000000  273.000000      273.000000
# mean     1.450461    1.459627    1.440310    1.449654        0.044938
# std      0.115037    0.112794    0.117437    0.115626        0.003586
# min      1.245300    1.259000    1.232700    1.245400        0.038600
# 25%      1.340800    1.344500    1.327600    1.336400        0.041400
# 50%      1.471500    1.479200    1.463500    1.471000        0.045600
# 75%      1.557700    1.564300    1.550200    1.558000        0.048300
# max      1.599100    1.603800    1.586600    1.599000        0.049600
