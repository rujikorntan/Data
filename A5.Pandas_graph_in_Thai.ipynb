# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/thai_unicode.csv', index_col='Province')
df
# Out:
#                Year      Pop
# Province
# กรุงเทพมหานคร  2556  5686252
# นครราชสีมา     2556  2610164
# อุบลราชธานี    2556  1836523
# ขอนแก่น        2556  1781655
# เชียงใหม่      2556  1666888
# กรุงเทพมหานคร  2555  5673560
# นครราชสีมา     2555  2601167
# อุบลราชธานี    2555  1826920
# ขอนแก่น        2555  1774816
# เชียงใหม่      2555  1655642
# กรุงเทพมหานคร  2554  5674843
# นครราชสีมา     2554  2585325
# อุบลราชธานี    2554  1816057
# ขอนแก่น        2554  1766066
# เชียงใหม่      2554  1646144
# กรุงเทพมหานคร  2553  5701394
# นครราชสีมา     2553  2582089
# อุบลราชธานี    2553  1813088
# ขอนแก่น        2553  1767601
# เชียงใหม่      2553  1640479
# กรุงเทพมหานคร  2552  5702595
# นครราชสีมา     2552  2571292
# อุบลราชธานี    2552  1803754
# ขอนแก่น        2552  1762242
# เชียงใหม่      2552  1632548
# กรุงเทพมหานคร  2551  5710883
# นครราชสีมา     2551  2565117
# อุบลราชธานี    2551  1795453
# ขอนแก่น        2551  1756101
# เชียงใหม่      2551  1670317
# ...

# %%
df[df.Year==2556]['Pop'].plot(kind = 'barh');
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['Angsananew'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.rcParams['font.family']='Tahoma' #change font

# %%
df[df.Year==2556]['Pop'].plot(kind = 'barh');

# %%
df[df.Year==2556]['Pop'].plot.bar(figsize = (5,5));

# %%
plt.rcParams['font.size'] = 18

# %%
df[df.Year == 2556]['Pop'].plot(kind='bar')
