# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df.head()
# Out:
#                          name       genus   vore         order  conservation  \
# 0                     Cheetah    Acinonyx  carni     Carnivora            lc
# 1                  Owl monkey       Aotus   omni      Primates           NaN
# 2             Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3  Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                         Cow         Bos  herbi  Artiodactyla  domesticated
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0         12.1        NaN          NaN   11.9      NaN   50.000
# 1         17.0        1.8          NaN    7.0  0.01550    0.480
# 2         14.4        2.4          NaN    9.6      NaN    1.350
# 3         14.9        2.3     0.133333    9.1  0.00029    0.019
# 4          4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
df.sort_values('sleep_total')
# Out:
#                               name          genus     vore            order  \
# 29                         Giraffe        Giraffa    herbi     Artiodactyla
# 30                     Pilot whale  Globicephalus    carni          Cetacea
# 22                           Horse          Equus    herbi   Perissodactyla
# 9                         Roe deer      Capreolus    herbi     Artiodactyla
# 23                          Donkey          Equus    herbi   Perissodactyla
# 35                African elephant      Loxodonta    herbi      Proboscidea
# 58                    Caspian seal          Phoca    carni        Carnivora
# 48                           Sheep           Ovis    herbi     Artiodactyla
# 20                  Asian elephant        Elephas    herbi      Proboscidea
# 4                              Cow            Bos    herbi     Artiodactyla
# 76                 Brazilian tapir        Tapirus    herbi   Perissodactyla
# ...

# %%
df.sort_values('sleep_total', ascending=False)         # ascending=False เรียงจาก มาก ไป น้อย
# Out:
#                               name          genus     vore            order  \
# 42                Little brown bat         Myotis  insecti       Chiroptera
# 21                   Big brown bat      Eptesicus  insecti       Chiroptera
# 36            Thick-tailed opposum     Lutreolina    carni  Didelphimorphia
# 61                 Giant armadillo     Priodontes  insecti        Cingulata
# 19          North American Opossum      Didelphis     omni  Didelphimorphia
# 17            Long-nosed armadillo        Dasypus    carni        Cingulata
# 1                       Owl monkey          Aotus     omni         Primates
# 69          Arctic ground squirrel   Spermophilus    herbi         Rodentia
# 71  Golden-mantled ground squirrel   Spermophilus    herbi         Rodentia
# 50                           Tiger       Panthera    carni        Carnivora
# 75       Eastern american chipmunk         Tamias    herbi         Rodentia
# ...

# %%
df[(df.sleep_total > 5)&(df.awake > 10)].sort_values('name')
# Out:
#                               name          genus     vore           order  \
# 15       African giant pouched rat     Cricetomys     omni        Rodentia
# 64           African striped mouse      Rhabdomys     omni        Rodentia
# 81                      Arctic fox         Vulpes    carni       Carnivora
# 53                          Baboon          Papio     omni        Primates
# 79            Bottle-nosed dolphin       Tursiops    carni         Cetacea
# 0                          Cheetah       Acinonyx    carni       Carnivora
# 49                      Chimpanzee            Pan     omni        Primates
# 13                      Chinchilla     Chinchilla    herbi        Rodentia
# 59                 Common porpoise       Phocoena    carni         Cetacea
# 67                      Cotton rat       Sigmodon    herbi        Rodentia
# 56                      Deer mouse     Peromyscus      NaN        Rodentia
# ...

# %%
df.columns.str.contains('vore')
# Out:
# array([False, False,  True, False, False, False, False, False, False,
#        False, False])

# %%
df.columns[df.columns.str.contains('vore')]
# Out:
# Index(['vore'], dtype='object')

# %%
df[df.columns[df.columns.str.contains('vore|conservation')]]
# Out:
#        vore  conservation
# 0     carni            lc
# 1      omni           NaN
# 2     herbi            nt
# 3      omni            lc
# 4     herbi  domesticated
# 5     herbi           NaN
# 6     carni            vu
# 7       NaN           NaN
# 8     carni  domesticated
# 9     herbi            lc
# 10    herbi            lc
# 11    herbi  domesticated
# 12     omni            lc
# 13    herbi  domesticated
# 14     omni            lc
# 15     omni           NaN
# 16     omni            lc
# 17    carni            lc
# 18    herbi            lc
# 19     omni            lc
# 20    herbi            en
# 21  insecti            lc
# 22    herbi  domesticated
# 23    herbi  domesticated
# 24     omni            lc
# 25     omni            lc
# 26    herbi           NaN
# 27    carni  domesticated
# 28     omni           NaN
# 29    herbi            cd
# ..      ...           ...
# 53     omni           NaN
# 54      NaN            lc
# 55     omni            lc
# ...

# %%
df.sort_values(['vore', 'sleep_total'])
# Out:
#                           name          genus     vore            order  \
# 30                 Pilot whale  Globicephalus    carni          Cetacea
# 58                Caspian seal          Phoca    carni        Carnivora
# 79        Bottle-nosed dolphin       Tursiops    carni          Cetacea
# 59             Common porpoise       Phocoena    carni          Cetacea
# 31                   Gray seal   Haliochoerus    carni        Carnivora
# 80                       Genet        Genetta    carni        Carnivora
# 6            Northern fur seal    Callorhinus    carni        Carnivora
# 82                     Red fox         Vulpes    carni        Carnivora
# 8                          Dog          Canis    carni        Carnivora
# 51                      Jaguar       Panthera    carni        Carnivora
# 44                  Slow loris      Nyctibeus    carni         Primates
# 0                      Cheetah       Acinonyx    carni        Carnivora
# ...

# %%
df.sort_values(['vore', 'sleep_total'], ascending=[True, False])
# Out:
#                               name          genus     vore            order  \
# 36            Thick-tailed opposum     Lutreolina    carni  Didelphimorphia
# 17            Long-nosed armadillo        Dasypus    carni        Cingulata
# 50                           Tiger       Panthera    carni        Carnivora
# 46      Northern grasshopper mouse      Onychomys    carni         Rodentia
# 52                            Lion       Panthera    carni        Carnivora
# 27                    Domestic cat          Felis    carni        Carnivora
# 81                      Arctic fox         Vulpes    carni        Carnivora
# 0                          Cheetah       Acinonyx    carni        Carnivora
# 44                      Slow loris      Nyctibeus    carni         Primates
# 51                          Jaguar       Panthera    carni        Carnivora
# 8                              Dog          Canis    carni        Carnivora
# ...

# %% [markdown]
# # Sort by index

# %%
df2 = df.set_index('name')
df2
# Out:
#                                         genus     vore            order  \
# name
# Cheetah                              Acinonyx    carni        Carnivora
# Owl monkey                              Aotus     omni         Primates
# Mountain beaver                    Aplodontia    herbi         Rodentia
# Greater short-tailed shrew            Blarina     omni     Soricomorpha
# Cow                                       Bos    herbi     Artiodactyla
# Three-toed sloth                     Bradypus    herbi           Pilosa
# Northern fur seal                 Callorhinus    carni        Carnivora
# Vesper mouse                          Calomys      NaN         Rodentia
# Dog                                     Canis    carni        Carnivora
# Roe deer                            Capreolus    herbi     Artiodactyla
# Goat                                    Capri    herbi     Artiodactyla
# Guinea pig                              Cavis    herbi         Rodentia
# ...

# %%
df2.sort_index(inplace=True)    
df2
# Out:
#                                         genus     vore            order  \
# name
# African elephant                    Loxodonta    herbi      Proboscidea
# African giant pouched rat          Cricetomys     omni         Rodentia
# African striped mouse               Rhabdomys     omni         Rodentia
# Arctic fox                             Vulpes    carni        Carnivora
# Arctic ground squirrel           Spermophilus    herbi         Rodentia
# Asian elephant                        Elephas    herbi      Proboscidea
# Baboon                                  Papio     omni         Primates
# Big brown bat                       Eptesicus  insecti       Chiroptera
# Bottle-nosed dolphin                 Tursiops    carni          Cetacea
# Brazilian tapir                       Tapirus    herbi   Perissodactyla
# Caspian seal                            Phoca    carni        Carnivora
# Cheetah                              Acinonyx    carni        Carnivora
# ...

# %%
df3 = df.set_index(['vore', 'name'])
df3
# Out:
#                                                 genus            order  \
# vore    name
# carni   Cheetah                              Acinonyx        Carnivora
# omni    Owl monkey                              Aotus         Primates
# herbi   Mountain beaver                    Aplodontia         Rodentia
# omni    Greater short-tailed shrew            Blarina     Soricomorpha
# herbi   Cow                                       Bos     Artiodactyla
#         Three-toed sloth                     Bradypus           Pilosa
# carni   Northern fur seal                 Callorhinus        Carnivora
# NaN     Vesper mouse                          Calomys         Rodentia
# carni   Dog                                     Canis        Carnivora
# herbi   Roe deer                            Capreolus     Artiodactyla
#         Goat                                    Capri     Artiodactyla
#         Guinea pig                              Cavis         Rodentia
# ...

# %%
df3.sort_index(inplace=True)

# %%
df3
# Out:
#                                             genus            order  \
# vore    name
# carni   Arctic fox                         Vulpes        Carnivora
#         Bottle-nosed dolphin             Tursiops          Cetacea
#         Caspian seal                        Phoca        Carnivora
#         Cheetah                          Acinonyx        Carnivora
#         Common porpoise                  Phocoena          Cetacea
#         Dog                                 Canis        Carnivora
#         Domestic cat                        Felis        Carnivora
#         Genet                             Genetta        Carnivora
#         Gray seal                    Haliochoerus        Carnivora
#         Jaguar                           Panthera        Carnivora
#         Lion                             Panthera        Carnivora
#         Long-nosed armadillo              Dasypus        Cingulata
#         Northern fur seal             Callorhinus        Carnivora
# ...

# %% [markdown]
# # Sort by column name

# %%
df4 = pd.read_table('https://github.com/prasertcbs/tutorial/raw/master/score_a.tsv')
df4
# Out:
#    studentid  math1  eng1  sci1  math2  eng2  sci2  math3  eng3  sci3
# 0       C215     10     9     4      7     5     6      7     6     9
# 1       C211      6    10     8     10     6     7      6     5    10
# 2       C305      8     5     4      6     3     7     10    10     5
# 3       B344      4     8     7      6     8     7      4    10     8
# 4       A312      9     8    10      8     6     9      5    10     9
# 5       B243      4     6     6      6     5     3      8     6     6
# 6       B304      4     4     4      6     7     4      7     9     6
# 7       A349      4     4     7      7     6     6      9     5     8
# 8       C409      4     4     4      8     6     8     10     9     6
# 9       C446      4    10     4      3     5     4     10     7     7
# 10      A398      4     6     8      5     5     4      7     5     8

# %%
df4.sort_index(axis=1, inplace=True)

# %%
df4
# Out:
#     eng1  eng2  eng3  math1  math2  math3  sci1  sci2  sci3 studentid
# 0      9     5     6     10      7      7     4     6     9      C215
# 1     10     6     5      6     10      6     8     7    10      C211
# 2      5     3    10      8      6     10     4     7     5      C305
# 3      8     8    10      4      6      4     7     7     8      B344
# 4      8     6    10      9      8      5    10     9     9      A312
# 5      6     5     6      4      6      8     6     3     6      B243
# 6      4     7     9      4      6      7     4     4     6      B304
# 7      4     6     5      4      7      9     7     6     8      A349
# 8      4     6     9      4      8     10     4     8     6      C409
# 9     10     5     7      4      3     10     4     4     7      C446
# 10     6     5     5      4      5      7     8     4     8      A398

# %%
df4.set_index('studentid', inplace=True)

# %%
df4
# Out:
#            eng1  eng2  eng3  math1  math2  math3  sci1  sci2  sci3
# studentid
# C215          9     5     6     10      7      7     4     6     9
# C211         10     6     5      6     10      6     8     7    10
# C305          5     3    10      8      6     10     4     7     5
# B344          8     8    10      4      6      4     7     7     8
# A312          8     6    10      9      8      5    10     9     9
# B243          6     5     6      4      6      8     6     3     6
# B304          4     7     9      4      6      7     4     4     6
# A349          4     6     5      4      7      9     7     6     8
# C409          4     6     9      4      8     10     4     8     6
# C446         10     5     7      4      3     10     4     4     7
# A398          6     5     5      4      5      7     8     4     8
