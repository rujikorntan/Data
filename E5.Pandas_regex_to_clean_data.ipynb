# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBlackend.figure_format ='retina'

# %%
from datetime import datetime

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_unicorn_startup_companies' , header=0, match= 'Twitter')

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]
df
# Out:
#                     Company   last valuation      valuation date  \
# 0                  Facebook    US$50 billion        January 2011
# 1                   Alibaba    US$42 billion           June 2016
# 2                   Spotify  US$8.53 billion       March 2016[5]
# 3                  Snap Inc  US$19.3 billion         May 2016[5]
# 4                     Zynga   US$9.1 billion       February 2011
# 5                Uber China     US$9 billion        January 2016
# 6                   Twitter     US$8 billion      September 2011
# 7                    Square     US$6 billion        October 2014
# 8                Stemcentrx     US$5 billion      September 2015
# 9                   Groupon  US$4.75 billion   December 2010[89]
# 10                     Ucar   US$4.4 billion          March 2017
# 11                  Zalando  US$4.03 billion       November 2013
# 12             Lending Club   US$3.8 billion         August 2014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
# Company           62 non-null object
# last valuation    56 non-null object
# valuation date    56 non-null object
# exit date         62 non-null object
# exit              62 non-null object
# exit valuation    62 non-null object
# Country           62 non-null object
# dtypes: object(7)
# memory usage: 3.5+ KB

# %%
df.columns = df.columns.str.replace(r' ','_')

# %%
df
# Out:
#                     Company   last_valuation      valuation_date  \
# 0                  Facebook    US$50 billion        January 2011
# 1                   Alibaba    US$42 billion           June 2016
# 2                   Spotify  US$8.53 billion       March 2016[5]
# 3                  Snap Inc  US$19.3 billion         May 2016[5]
# 4                     Zynga   US$9.1 billion       February 2011
# 5                Uber China     US$9 billion        January 2016
# 6                   Twitter     US$8 billion      September 2011
# 7                    Square     US$6 billion        October 2014
# 8                Stemcentrx     US$5 billion      September 2015
# 9                   Groupon  US$4.75 billion   December 2010[89]
# 10                     Ucar   US$4.4 billion          March 2017
# 11                  Zalando  US$4.03 billion       November 2013
# 12             Lending Club   US$3.8 billion         August 2014
# ...

# %%
df['valuation_date_new'] =df.valuation_date.str.replace('\[.*\]','')         #.* = ตัวอักษร

# %%
df
# Out:
#                     Company   last_valuation      valuation_date  \
# 0                  Facebook    US$50 billion        January 2011
# 1                   Alibaba    US$42 billion           June 2016
# 2                   Spotify  US$8.53 billion       March 2016[5]
# 3                  Snap Inc  US$19.3 billion         May 2016[5]
# 4                     Zynga   US$9.1 billion       February 2011
# 5                Uber China     US$9 billion        January 2016
# 6                   Twitter     US$8 billion      September 2011
# 7                    Square     US$6 billion        October 2014
# 8                Stemcentrx     US$5 billion      September 2015
# 9                   Groupon  US$4.75 billion   December 2010[89]
# 10                     Ucar   US$4.4 billion          March 2017
# 11                  Zalando  US$4.03 billion       November 2013
# 12             Lending Club   US$3.8 billion         August 2014
# ...

# %%
df['last_valuation_new'] = df.last_valuation.str.replace('[^\d\.]','').astype(float)      # ^=ยกเว้น

# %%
df
# Out:
#                     Company   last_valuation      valuation_date  \
# 0                  Facebook    US$50 billion        January 2011
# 1                   Alibaba    US$42 billion           June 2016
# 2                   Spotify  US$8.53 billion       March 2016[5]
# 3                  Snap Inc  US$19.3 billion         May 2016[5]
# 4                     Zynga   US$9.1 billion       February 2011
# 5                Uber China     US$9 billion        January 2016
# 6                   Twitter     US$8 billion      September 2011
# 7                    Square     US$6 billion        October 2014
# 8                Stemcentrx     US$5 billion      September 2015
# 9                   Groupon  US$4.75 billion   December 2010[89]
# 10                     Ucar   US$4.4 billion          March 2017
# 11                  Zalando  US$4.03 billion       November 2013
# 12             Lending Club   US$3.8 billion         August 2014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 9 columns):
# Company               62 non-null object
# last_valuation        56 non-null object
# valuation_date        56 non-null object
# exit_date             62 non-null object
# exit                  62 non-null object
# exit_valuation        62 non-null object
# Country               62 non-null object
# valuation_date_new    56 non-null object
# last_valuation_new    56 non-null float64
# dtypes: float64(1), object(8)
# memory usage: 4.4+ KB

# %%
pd.to_datetime(df.valuation_date_new)
# Out:
# 0    2011-01-01
# 1    2016-06-01
# 2    2016-03-01
# 3    2016-05-01
# 4    2011-02-01
# 5    2016-01-01
# 6    2011-09-01
# 7    2014-10-01
# 8    2015-09-01
# 9    2010-12-01
# 10   2017-03-01
# 11   2013-11-01
# 12   2014-08-01
# 13   2014-04-01
# 14   2014-10-01
# 15   2014-08-01
# 16   2016-05-01
# 17   2011-05-01
# 18   2014-07-01
# 19   2012-12-01
# 20   2017-09-01
# 21   2015-11-01
# 22   2014-03-01
# 23   2016-01-01
# 24   2014-12-01
# 25   2016-09-01
# 26   2013-07-01
# 27   2012-11-01
# 28   2015-05-01
# 29   2015-11-01
#         ...
# 32   2010-10-01
# 33   2014-04-01
# 34   2016-07-01
# 35          NaT
# 36   2014-09-01
# 37   2013-08-01
# 38   2015-02-01
# 39   2014-08-01
# 40   2012-11-01
# 41   2015-06-01
# 42   2016-02-01
# 43   2015-07-01
# 44   2015-03-01
# 45   2014-02-01
# 46   2013-12-01
# 47   2013-05-01
# 48   2015-01-01
# 49   2014-04-01
# 50          NaT
# 51   2016-04-01
# 52   2016-02-01
# 53   2016-02-01
# 54   2015-01-01
# 55          NaT
# ...

# %%
df['date'] = pd.to_datetime(df.valuation_date.str.replace('\[.*\]',''))

# %%
df
# Out:
#                     Company   last_valuation      valuation_date  \
# 0                  Facebook    US$50 billion        January 2011
# 1                   Alibaba    US$42 billion           June 2016
# 2                   Spotify  US$8.53 billion       March 2016[5]
# 3                  Snap Inc  US$19.3 billion         May 2016[5]
# 4                     Zynga   US$9.1 billion       February 2011
# 5                Uber China     US$9 billion        January 2016
# 6                   Twitter     US$8 billion      September 2011
# 7                    Square     US$6 billion        October 2014
# 8                Stemcentrx     US$5 billion      September 2015
# 9                   Groupon  US$4.75 billion   December 2010[89]
# 10                     Ucar   US$4.4 billion          March 2017
# 11                  Zalando  US$4.03 billion       November 2013
# 12             Lending Club   US$3.8 billion         August 2014
# ...
