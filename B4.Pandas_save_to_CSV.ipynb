# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/country_region.csv')
df.head()
# Out:
#           country alpha2 alpha3   region        subregion
# 0     Afghanistan     AF    AFG     Asia    Southern Asia
# 1   Åland Islands     AX    ALA   Europe  Northern Europe
# 2         Albania     AL    ALB   Europe  Southern Europe
# 3         Algeria     DZ    DZA   Africa  Northern Africa
# 4  American Samoa     AS    ASM  Oceania        Polynesia

# %%
df.to_csv('datasheet/demo1.csv')

# %%
df.to_csv('datasheet/demo2.csv', index_label='id')

# %%
df = pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/country_region.csv')

# %%
df.to_csv('datasheet/demo3.csv', index=False)

# %% [markdown]
# ## Save by choose column

# %%
df = pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/country_region.csv')

# %%
df.columns
# Out:
# Index(['country', 'alpha2', 'alpha3', 'region', 'subregion'], dtype='object')

# %%
df.to_csv('datasheet/demo4.csv', columns=['country', 'alpha2', 'alpha3'], index_label='id')

# %%
df[df.region=='Asia']
# Out:
#                                      country alpha2 alpha3 region  \
# 0                                Afghanistan     AF    AFG   Asia
# 11                                   Armenia     AM    ARM   Asia
# 15                                Azerbaijan     AZ    AZE   Asia
# 17                                   Bahrain     BH    BHR   Asia
# 18                                Bangladesh     BD    BGD   Asia
# 25                                    Bhutan     BT    BTN   Asia
# 33                         Brunei Darussalam     BN    BRN   Asia
# 38                                  Cambodia     KH    KHM   Asia
# 45                                     China     CN    CHN   Asia
# 58                                    Cyprus     CY    CYP   Asia
# 81                                   Georgia     GE    GEO   Asia
# 99                                 Hong Kong     HK    HKG   Asia
# 102                                    India     IN    IND   Asia
# ...

# %%
df[df.region=='Asia'].to_csv('datasheet/demo5.csv')

# %%
df.region.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas', nan],
#       dtype=object)

# %%
df[df.region.notna()].region.unique()                       #เอา na ออก(ตัวว่าง)
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas'], dtype=object)

# %%
for r in df[df.region.notna()].region.unique():
    df[df.region==r].to_csv(f'datasheet/demo{r}.csv', index=False)
