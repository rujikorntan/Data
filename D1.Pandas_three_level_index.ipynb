# %%
import pandas as pd

# %%
df = pd.read_table('https://github.com/prasertcbs/basic-dataset/raw/master/gapminder.tsv', index_col=['continent','country', 'year'])
df
# Out:
#                             lifeExp       pop    gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333   779.445314
#                       1957   30.332   9240934   820.853030
#                       1962   31.997  10267083   853.100710
#                       1967   34.020  11537966   836.197138
#                       1972   36.088  13079460   739.981106
#                       1977   38.438  14880372   786.113360
#                       1982   39.854  12881816   978.011439
#                       1987   40.822  13867957   852.395945
#                       1992   41.674  16317921   649.341395
#                       1997   41.763  22227415   635.341351
#                       2002   42.129  25268405   726.734055
#                       2007   43.828  31889923   974.580338
# Europe    Albania     1952   55.230   1282697  1601.056136
#                       1957   59.280   1476505  1942.284244
# ...

# %%
df.sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-72bf506e9385> in <module>()
# ----> 1 df.sort_index(levels=(2,3))
#
# TypeError: sort_index() got an unexpected keyword argument 'levels'

# %%
df.sort_index(inplace=True)
df
# Out:
#                                lifeExp       pop     gdpPercap
# continent country        year
# Africa    Algeria        1952   43.077   9279525   2449.008185
#                          1957   45.685  10270856   3013.976023
#                          1962   48.303  11000948   2550.816880
#                          1967   51.407  12760499   3246.991771
#                          1972   54.518  14760787   4182.663766
#                          1977   58.014  17152804   4910.416756
#                          1982   61.368  20033753   5745.160213
#                          1987   65.799  23254956   5681.358539
#                          1992   67.744  26298373   5023.216647
#                          1997   69.152  29072015   4797.295051
#                          2002   70.994  31287142   5288.040382
#                          2007   72.301  33333216   6223.367465
#           Angola         1952   30.015   4232095   3520.610273
# ...

# %%
df.loc[('Asia', 'Thailand')]
# Out:
#       lifeExp       pop    gdpPercap
# year
# 1952   50.848  21289402   757.797418
# 1957   53.630  25041917   793.577415
# 1962   56.061  29263397  1002.199172
# 1967   58.285  34024249  1295.460660
# 1972   60.405  39276153  1524.358936
# 1977   62.494  44148285  1961.224635
# 1982   64.597  48827160  2393.219781
# 1987   66.084  52910342  2982.653773
# 1992   67.298  56667095  4616.896545
# 1997   67.521  60216677  5852.625497
# 2002   68.564  62806748  5913.187529
# 2007   70.616  65068149  7458.396327

# %%
df.loc[('Asia', 'Thailand')].loc[1952].to_frame().T          #df.loc['Asia'].loc['Thailand'].loc[1952].to_frame().T
# Out:
#       lifeExp         pop   gdpPercap
# 1952   50.848  21289402.0  757.797418

# %%
df.loc[('Asia', 'Thailand')].loc[1952:2002]['pop'].to_frame()
# Out:
#            pop
# year
# 1952  21289402
# 1957  25041917
# 1962  29263397
# 1967  34024249
# 1972  39276153
# 1977  44148285
# 1982  48827160
# 1987  52910342
# 1992  56667095
# 1997  60216677
# 2002  62806748

# %%
# %matplotlib inline
df.loc[('Asia', 'Thailand')].loc[1952:2002]['pop'].sort_values().plot(kind='barh');

# %%
df.index.get_level_values(0)
# Out:
# Index(['Africa', 'Africa', 'Africa', 'Africa', 'Africa', 'Africa', 'Africa',
#        'Africa', 'Africa', 'Africa',
#        ...
#        'Oceania', 'Oceania', 'Oceania', 'Oceania', 'Oceania', 'Oceania',
#        'Oceania', 'Oceania', 'Oceania', 'Oceania'],
#       dtype='object', name='continent', length=1704)

# %%
df.index.get_level_values(2)
# Out:
# Int64Index([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997,
#             ...
#             1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007],
#            dtype='int64', name='year', length=1704)

# %%
df[df.index.get_level_values(2)==2002]
# Out:
#                                          lifeExp       pop     gdpPercap
# continent country                  year
# Africa    Algeria                  2002   70.994  31287142   5288.040382
#           Angola                   2002   41.003  10866106   2773.287312
#           Benin                    2002   54.406   7026113   1372.877931
#           Botswana                 2002   46.634   1630347  11003.605080
#           Burkina Faso             2002   50.650  12251209   1037.645221
#           Burundi                  2002   47.360   7021078    446.403513
#           Cameroon                 2002   49.856  15929988   1934.011449
#           Central African Republic 2002   43.308   4048013    738.690607
#           Chad                     2002   50.525   8835739   1156.181860
#           Comoros                  2002   62.974    614382   1075.811558
#           Congo, Dem. Rep.         2002   44.966  55379852    241.165877
# ...
