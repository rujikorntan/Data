# %%
import pandas as pd

# %%
df = pd.read_clipboard()           #Ctrl+c
df
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#    Position                Track Name         Artist
# 0         1                Better Now    Post Malone
# 1         2                  All Mine     Kanye West
# 2         3  One Kiss (with Dua Lipa)  Calvin Harris
# 3         4                Ghost Town     Kanye West
# 4         5                     Yikes     Kanye West
# 5         6             Nice For What          Drake
# 6         7                 I Like It        Cardi B
# 7         8      No Tears Left To Cry  Ariana Grande
# 8         9                God's Plan          Drake

# %%
df = pd.read_clipboard(names = ['Position', 'Track Name', 'Artist'])
df
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#     Position                      Track Name               Artist
# 0         10                     Back To You         Selena Gomez
# 1         11                    Lucid Dreams           Juice WRLD
# 2         12                Te Botรฉ - Remix           Nio Garcia
# 3         13                 This Is America     Childish Gambino
# 4         14    Psycho (feat. Ty Dolla $ign)          Post Malone
# 5         15                  Wouldn't Leave           Kanye West
# 6         16                               X            Nicky Jam
# 7         17                      Youngblood  5 Seconds of Summer
# ...

# %%
df = pd.read_clipboard(index_col = 0 ,names = ['Position', 'Track Name', 'Artist'])
df
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#                               Track Name               Artist
# Position
# 10                           Back To You         Selena Gomez
# 11                          Lucid Dreams           Juice WRLD
# 12                      Te Botรฉ - Remix           Nio Garcia
# 13                       This Is America     Childish Gambino
# 14          Psycho (feat. Ty Dolla $ign)          Post Malone
# 15                        Wouldn't Leave           Kanye West
# 16                                     X            Nicky Jam
# 17                            Youngblood  5 Seconds of Summer
# ...

# %% [markdown]
# Symbol,Date,Open,High,Low,Close,Adj Close,Volume
# bbl,2017-02-01,174.5,175.5,173.5,175.5,169.355362,5953500.0
# bbl,2017-02-02,175.0,177.0,174.5,175.5,169.355362,5250500.0

# %%
df = pd.read_clipboard(sep = ',')                          #อ่านไฟล์จาก csv
df
# Out:
#   Symbol        Date   Open   High    Low  Close   Adj Close     Volume
# 0    bbl  2017-02-01  174.5  175.5  173.5  175.5  169.355362  5953500.0
# 1    bbl  2017-02-02  175.0  177.0  174.5  175.5  169.355362  5250500.0

# %% [markdown]
# Year	TV	Camera	Phone
# 2011	THB556,300	THB943,620	THB518,600
# 2012	THB344,200	THB583,370	THB323,920
# 2013	THB727,320	THB548,640	THB941,500
# 2014	THB462,870	THB661,520	THB650,570
# 2015	THB916,600	THB974,180	THB148,740
# 2016	THB176,830	THB588,990	THB910,570
# 2017	THB745,550	THB896,860	THB982,820

# %%
df = pd.read_clipboard(sep='\t')                      #อ่านไฟล์จาก tsv
df
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#    Year          TV      Camera       Phone
# 0  2011  THB556,300  THB943,620  THB518,600
# 1  2012  THB344,200  THB583,370  THB323,920
# 2  2013  THB727,320  THB548,640  THB941,500
# 3  2014  THB462,870  THB661,520  THB650,570
# 4  2015  THB916,600  THB974,180  THB148,740
# 5  2016  THB176,830  THB588,990  THB910,570
# 6  2017  THB745,550  THB896,860  THB982,820

# %% [markdown]
# https://finance.yahoo.com/quote/SCC.BK/history?p=SCC.BK

# %%
df = pd.read_clipboard(index_col=0, parse_dates = True)
df
# Out:
# C:\Users\ruji-\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#              Open   High    Low  Close*  Adj Close**     Volume
# Date
# 2018-06-08  450.0  452.0  446.0   446.0        446.0  2,979,000
# 2018-06-07  452.0  456.0  450.0   450.0        450.0  2,058,300
# 2018-06-06  458.0  460.0  450.0   450.0        450.0  3,713,400
# 2018-06-05  454.0  458.0  450.0   458.0        458.0  2,159,700
# 2018-06-04  452.0  454.0  450.0   452.0        452.0  1,901,100
# 2018-06-01  446.0  456.0  444.0   452.0        452.0  3,812,800

# %%
# %matplotlib inline
df['Close*'].plot(rot = 0, figsize =(10,10) )
