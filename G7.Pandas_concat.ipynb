# %%
import pandas as pd

# %%
east = pd.read_html('https://th.wikipedia.org/wiki/%E0%B8%88%E0%B8%B1%E0%B8%87%E0%B8%AB%E0%B8%A7%E0%B8%B1%E0%B8%94%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2',
                 match='จันทบุรี', header=0)

# %%
len(east)
# Out:
# 8

# %%
east[0]
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0             จันทบุรี            Chanthaburi             514616
# 1           ฉะเชิงเทรา           Chachoengsao             673933
# 2               ชลบุรี              Chon Buri            1509125
# 3                 ตราด                   Trat             220921
# 4           ปราจีนบุรี           Prachin Buri             466572
# 5                ระยอง                 Rayong             626402
# 6              สระแก้ว                Sa Kaeo             485632
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# 0            6338.0                             81.2    0.754              จบ
# 1            5351.0                            125.9    0.708              ฉช
# 2            4363.0                            345.9    0.889              ชบ
# 3            2819.0                             78.4    0.675              ตร
# ...

# %%
east = east[0]

# %%
west = pd.read_html('https://th.wikipedia.org/wiki/%E0%B8%88%E0%B8%B1%E0%B8%87%E0%B8%AB%E0%B8%A7%E0%B8%B1%E0%B8%94%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2',
                   match='ตาก', header=0)

# %%
len(west)
# Out:
# 5

# %%
west[0]
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0            กาญจนบุรี           Kanchanaburi             839776
# 1                  ตาก                    Tak             525684
# 2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3             เพชรบุรี            Phetchaburi             464033
# 4              ราชบุรี             Ratchaburi             839075
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# 0           19483.2                             43.1    0.733              กจ
# 1           16406.6                             32.0    0.735              ตก
# 2            6367.6                             80.0    0.868              ปข
# 3            6225.1                             74.5    0.798              พบ
# 4            5196.5                            161.5    0.726              รบ
#
#   ตัวย่อ อักษรโรมัน รหัส ไอเอสโอ รหัสฟิปส์
# 0               KRI        TH-71      TH50
# ...

# %%
west=west[0]

# %%
df = pd.concat([west, east])

# %%
df
# Out:
#   ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0            กาญจนบุรี           Kanchanaburi             839776
# 1                  ตาก                    Tak             525684
# 2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3             เพชรบุรี            Phetchaburi             464033
# 4              ราชบุรี             Ratchaburi             839075
# 0             จันทบุรี            Chanthaburi             514616
# 1           ฉะเชิงเทรา           Chachoengsao             673933
# 2               ชลบุรี              Chon Buri            1509125
# 3                 ตราด                   Trat             220921
# 4           ปราจีนบุรี           Prachin Buri             466572
# 5                ระยอง                 Rayong             626402
# 6              สระแก้ว                Sa Kaeo             485632
#
#    พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2] ตัวย่อ อักษรไทย  \
# ...

# %%
df = pd.concat([west, east], ignore_index=True)

# %%
df
# Out:
#    ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0             กาญจนบุรี           Kanchanaburi             839776
# 1                   ตาก                    Tak             525684
# 2       ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
# 3              เพชรบุรี            Phetchaburi             464033
# 4               ราชบุรี             Ratchaburi             839075
# 5              จันทบุรี            Chanthaburi             514616
# 6            ฉะเชิงเทรา           Chachoengsao             673933
# 7                ชลบุรี              Chon Buri            1509125
# 8                  ตราด                   Trat             220921
# 9            ปราจีนบุรี           Prachin Buri             466572
# 10                ระยอง                 Rayong             626402
# 11              สระแก้ว                Sa Kaeo             485632
#
#     พื้นที่ (ตร.กม.)  ความหนาแน่น ประชากร (คน/ตร.กม.)  ดพม.[2]  \
# ...

# %%
df = pd.concat([west, east], keys=['ภาุคตะวันตก', 'ตะวันออก'])

# %%
df
# Out:
#               ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# ภาุคตะวันตก 0            กาญจนบุรี           Kanchanaburi             839776
#             1                  ตาก                    Tak             525684
#             2      ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
#             3             เพชรบุรี            Phetchaburi             464033
#             4              ราชบุรี             Ratchaburi             839075
# ตะวันออก    0             จันทบุรี            Chanthaburi             514616
#             1           ฉะเชิงเทรา           Chachoengsao             673933
#             2               ชลบุรี              Chon Buri            1509125
#             3                 ตราด                   Trat             220921
#             4           ปราจีนบุรี           Prachin Buri             466572
#             5                ระยอง                 Rayong             626402
# ...

# %%
south = pd.read_html('https://th.wikipedia.org/wiki/%E0%B8%88%E0%B8%B1%E0%B8%87%E0%B8%AB%E0%B8%A7%E0%B8%B1%E0%B8%94%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2',
                   match='พังงา', header=0)

# %%
len(south)
# Out:
# 5

# %%
south[0]
# Out:
#    ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# 0                กระบี่                  Krabi             469769
# 1                 ชุมพร               Chumphon             509650
# 2                  ตรัง                  Trang             643072
# 3         นครศรีธรรมราช    Nakhon Si Thammarat            1557482
# 4              นราธิวาส             Narathiwat             796239
# 5               ปัตตานี                Pattani             709796
# 6                 พังงา               Phangnga             267491
# 7                พัทลุง            Phatthalung             524857
# 8                ภูเก็ต                 Phuket             402017
# 9                  ยะลา                   Yala             527295
# 10                ระนอง                 Ranong             190399
# 11                สงขลา               Songkhla            1424230
# 12                 สตูล                  Satun             319700
# ...

# %%
south = south[0]

# %%
df = pd.concat([west, east, south], keys=['ภาุคตะวันตก', 'ตะวันออก', 'ภาคใต้'])

# %%
df
# Out:
#                ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  จำนวนประชากร (คน)  \
# ภาุคตะวันตก 0             กาญจนบุรี           Kanchanaburi             839776
#             1                   ตาก                    Tak             525684
#             2       ประจวบคีรีขันธ์    Prachuap Khiri Khan             509134
#             3              เพชรบุรี            Phetchaburi             464033
#             4               ราชบุรี             Ratchaburi             839075
# ตะวันออก    0              จันทบุรี            Chanthaburi             514616
#             1            ฉะเชิงเทรา           Chachoengsao             673933
#             2                ชลบุรี              Chon Buri            1509125
#             3                  ตราด                   Trat             220921
#             4            ปราจีนบุรี           Prachin Buri             466572
#             5                 ระยอง                 Rayong             626402
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         level_0  level_1 ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  \
# 0   ภาุคตะวันตก        0            กาญจนบุรี           Kanchanaburi
# 1   ภาุคตะวันตก        1                  ตาก                    Tak
# 2   ภาุคตะวันตก        2      ประจวบคีรีขันธ์    Prachuap Khiri Khan
# 3   ภาุคตะวันตก        3             เพชรบุรี            Phetchaburi
# 4   ภาุคตะวันตก        4              ราชบุรี             Ratchaburi
# 5      ตะวันออก        0             จันทบุรี            Chanthaburi
# 6      ตะวันออก        1           ฉะเชิงเทรา           Chachoengsao
# 7      ตะวันออก        2               ชลบุรี              Chon Buri
# 8      ตะวันออก        3                 ตราด                   Trat
# 9      ตะวันออก        4           ปราจีนบุรี           Prachin Buri
# 10     ตะวันออก        5                ระยอง                 Rayong
# 11     ตะวันออก        6              สระแก้ว                Sa Kaeo
# 12       ภาคใต้        0               กระบี่                  Krabi
# ...

# %%
df.rename(columns={'level_0':'region', 'level_1':'index'}, inplace=True)

# %%
df
# Out:
#          region  index ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  \
# 0   ภาุคตะวันตก      0            กาญจนบุรี           Kanchanaburi
# 1   ภาุคตะวันตก      1                  ตาก                    Tak
# 2   ภาุคตะวันตก      2      ประจวบคีรีขันธ์    Prachuap Khiri Khan
# 3   ภาุคตะวันตก      3             เพชรบุรี            Phetchaburi
# 4   ภาุคตะวันตก      4              ราชบุรี             Ratchaburi
# 5      ตะวันออก      0             จันทบุรี            Chanthaburi
# 6      ตะวันออก      1           ฉะเชิงเทรา           Chachoengsao
# 7      ตะวันออก      2               ชลบุรี              Chon Buri
# 8      ตะวันออก      3                 ตราด                   Trat
# 9      ตะวันออก      4           ปราจีนบุรี           Prachin Buri
# 10     ตะวันออก      5                ระยอง                 Rayong
# 11     ตะวันออก      6              สระแก้ว                Sa Kaeo
# 12       ภาคใต้      0               กระบี่                  Krabi
# ...

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#          region ชื่อจังหวัด อักษรไทย ชื่อจังหวัด อักษรโรมัน  \
# 0   ภาุคตะวันตก            กาญจนบุรี           Kanchanaburi
# 1   ภาุคตะวันตก                  ตาก                    Tak
# 2   ภาุคตะวันตก      ประจวบคีรีขันธ์    Prachuap Khiri Khan
# 3   ภาุคตะวันตก             เพชรบุรี            Phetchaburi
# 4   ภาุคตะวันตก              ราชบุรี             Ratchaburi
# 5      ตะวันออก             จันทบุรี            Chanthaburi
# 6      ตะวันออก           ฉะเชิงเทรา           Chachoengsao
# 7      ตะวันออก               ชลบุรี              Chon Buri
# 8      ตะวันออก                 ตราด                   Trat
# 9      ตะวันออก           ปราจีนบุรี           Prachin Buri
# 10     ตะวันออก                ระยอง                 Rayong
# 11     ตะวันออก              สระแก้ว                Sa Kaeo
# 12       ภาคใต้               กระบี่                  Krabi
# 13       ภาคใต้                ชุมพร               Chumphon
# 14       ภาคใต้                 ตรัง                  Trang
# ...
