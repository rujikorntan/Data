# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 1           audi                  a4    1.8  1999    4  manual(m5)   f   21
# 2           audi                  a4    2.0  2008    4  manual(m6)   f   20
# 3           audi                  a4    2.0  2008    4    auto(av)   f   21
# 4           audi                  a4    2.8  1999    6    auto(l5)   f   16
# 5           audi                  a4    2.8  1999    6  manual(m5)   f   18
# 6           audi                  a4    3.1  2008    6    auto(av)   f   18
# 7           audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
df['manufacturer'] = df.manufacturer.map(str.capitalize)

# %%
df
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           Audi                  a4    1.8  1999    4    auto(l5)   f   18
# 1           Audi                  a4    1.8  1999    4  manual(m5)   f   21
# 2           Audi                  a4    2.0  2008    4  manual(m6)   f   20
# 3           Audi                  a4    2.0  2008    4    auto(av)   f   21
# 4           Audi                  a4    2.8  1999    6    auto(l5)   f   16
# 5           Audi                  a4    2.8  1999    6  manual(m5)   f   18
# 6           Audi                  a4    3.1  2008    6    auto(av)   f   18
# 7           Audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           Audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           Audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          Audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
df[(df.manufacturer == 'Honda') & (df.cty >=25)]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         Honda  civic    1.6  1999    4  manual(m5)   f   28   33  r
# 101        Honda  civic    1.6  1999    4  manual(m5)   f   25   32  r
# 104        Honda  civic    1.8  2008    4  manual(m5)   f   26   34  r
# 105        Honda  civic    1.8  2008    4    auto(l5)   f   25   36  r
#
#           class
# 99   subcompact
# 101  subcompact
# 104  subcompact
# 105  subcompact

# %%
# df[(df.manufacturer=='Toyota') | (df.manufacturer=='Audi') |(df.manufacturer=='Honda')]
# df[df.manufacturer.str.contains('Toyota|Audi|Honda')]
# Check whether `values` are contained in Series.
df[df.manufacturer.isin(['Toyota', 'Audi', 'Honda'])]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0           Audi                      a4    1.8  1999    4    auto(l5)   f
# 1           Audi                      a4    1.8  1999    4  manual(m5)   f
# 2           Audi                      a4    2.0  2008    4  manual(m6)   f
# 3           Audi                      a4    2.0  2008    4    auto(av)   f
# 4           Audi                      a4    2.8  1999    6    auto(l5)   f
# 5           Audi                      a4    2.8  1999    6  manual(m5)   f
# 6           Audi                      a4    3.1  2008    6    auto(av)   f
# 7           Audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 8           Audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 9           Audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 10          Audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
df[~df.manufacturer.isin(['Toyota', 'Audi', 'Honda'])]  # ~ = ยกเว้น
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 18     Chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 19     Chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 20     Chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 21     Chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 22     Chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 23     Chevrolet            corvette    5.7  1999    8  manual(m6)   r   16
# 24     Chevrolet            corvette    5.7  1999    8    auto(l4)   r   15
# 25     Chevrolet            corvette    6.2  2008    8  manual(m6)   r   16
# 26     Chevrolet            corvette    6.2  2008    8    auto(s6)   r   15
# 27     Chevrolet            corvette    7.0  2008    8  manual(m6)   r   15
# 28     Chevrolet     k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   14
# ...
